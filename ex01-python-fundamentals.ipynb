# %% [markdown]
# ## Exercise 1 - Python fundamentals Part 1

# %% [markdown]
# **Important:** Before starting the exercise, it is highly recommended to read this guide first: [Jupyter Notebook guide](https://pentje.pages.labranet.jamk.fi/tt00cd84-material/guides/03-notebook-guide/)!

# %% [markdown]
# 1 Sentence is presented in the code cell below. Create a variable which has first ten and last ten characters concatenated.

# %%
s = "Gary must look towards the future in order to gather enough information from the target."

first_ten = s[:10]
last_ten = s[-10:]
print(first_ten)
print(last_ten)
# Out:
# Gary must
# he target.

# %% [markdown]
# 2 Count the number of white spaces between words from the previous sentence and divide that number with the length of the sentence (white spaces / length of the sentence).

# %%
space_count = s.count(' ')
length = len(s)

print(space_count/length)
# Out:
# 0.1590909090909091

# %% [markdown]
# 3 Add the following cars to the existing list of dictionary objects:
#     - Red Toyota Corolla (1985)
#     - Lightblue Ford Mustang (1965)
#     - Black Pontiac Firebird (1987)

# %%
cars = [{"make":"Ford","model":"escort","color":"green","year":1994},{"make":"Lexus","model":"IS250","color":"beige","year":2013},{"make":"Volvo","model":"S40","color":"blue","year":1998}]

toyota = {"make":"Toyota","model":"Corolla","color":"red","year":1985}
mustang = {"make":"Ford","model":"Mustang","color":"Lightblue","year":1965}

cars.append(toyota)
cars.append(mustang)

print(cars)
# Out:
# [{'make': 'Ford', 'model': 'escort', 'color': 'green', 'year': 1994}, {'make': 'Lexus', 'model': 'IS250', 'color': 'beige', 'year': 2013}, {'make': 'Volvo', 'model': 'S40', 'color': 'blue', 'year': 1998}, {'make': 'Toyota', 'model': 'Corolla', 'color': 'red', 'year': 1985}, {'make': 'Ford', 'model': 'Mustang', 'color': 'Lightblue', 'year': 1965}]

# %% [markdown]
# 4 Convert the sentence presented below to list using **existing commas (,)** in the sentence as separators. Then create a new list which contains only the last three items from the list.

# %%
s = "Occaecat short ribs incididunt laboris. Bresaola, brisket ex, landjaeger ad, boudin pariatur frankfurter eu flank. Enim tail short ribs, shoulder duis minim excepteur, deserunt lorem porchetta. Dolor chicken spare ribs, id in, ball, tip, hamburger labore venison consectetur cupidatat."

res = s.split(',')

new_list = res[-3:]
# print(res)
print(new_list)
# Out:
# [' ball', ' tip', ' hamburger labore venison consectetur cupidatat.']

# %% [markdown]
#  5 Below is a list containing words. Sort the words in the first half of the list by length in ascending order and words in the last half of the list so that words will be sorted alphabetically in descending order. Combine these list into one.

# %%
word_list = ["brainstorming","staff","north","outside","pass","leftover","offline","journey","globalize","zero","bandwidth","outsourcing","fruit","productive"]

first_half = word_list[:len(word_list)//2]
second_half =  word_list[len(word_list)//2:]

first_half_sorted = sorted(first_half, key=len)
second_half_sorted = sorted(second_half,reverse=True)

combined = first_half_sorted + second_half_sorted 
print(combined)
# Out:
# ['pass', 'staff', 'north', 'outside', 'offline', 'leftover', 'brainstorming', 'zero', 'productive', 'outsourcing', 'journey', 'globalize', 'fruit', 'bandwidth']
